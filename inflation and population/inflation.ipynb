# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('dataset.csv')

# %%
df.columns
# Out:
# Index(['date', 'inflation', 'total population', 'ferti_cosption', 'Agri_land',
#        'forest', 'land area', 'renew_e_c', 'acc_t_elect', 'c_corruption',
#        'tax_rev', 'gdp_per_cap'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              65 non-null     int64
#  1   inflation         65 non-null     float64
#  2   total population  65 non-null     float64
#  3   ferti_cosption    65 non-null     float64
#  4   Agri_land         65 non-null     float64
#  5   forest            33 non-null     float64
#  6   land area         62 non-null     float64
#  7   renew_e_c         32 non-null     float64
#  8   acc_t_elect       26 non-null     float64
#  9   c_corruption      25 non-null     float64
#  10  tax_rev           20 non-null     float64
#  11  gdp_per_cap       65 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 6.2 KB

# %%
df.drop(columns=['forest','land area','renew_e_c','acc_t_elect','c_corruption','tax_rev'],inplace=True)

# %%
dfc=df.columns

# %%
df.shape
# Out:
# (65, 6)

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
df_sc=scalar.fit_transform(df)
df=pd.DataFrame(data=df_sc,columns=dfc)
df
# Out:
#         date  inflation  total population  ferti_cosption     Agri_land  \
# 0   1.705606   0.676146          1.838263    1.810518e-16  1.626050e-15
# 1   1.652306   3.749014          1.779955    1.810518e-16  1.626050e-15
# 2   1.599005   1.903106          1.721042   -8.656193e-01  1.626050e-15
# 3   1.545705   0.144733          1.655637   -5.915652e-01  3.422625e-02
# 4   1.492405   0.186039          1.586312   -6.193097e-01  6.710283e-01
# ..       ...        ...               ...             ...           ...
# 60 -1.492405  -0.756108         -1.266619    2.647611e-01  1.130684e-01
# 61 -1.545705  -1.217505         -1.287562   -1.696793e-01 -6.071244e-01
# 62 -1.599005  -1.551799         -1.307567   -1.038333e+00 -6.677722e-01
# 63 -1.652306  -1.186340         -1.326693    2.065864e+00 -8.345537e-01
# 64 -1.705606  -0.287139         -1.345464    1.810518e-16  1.626050e-15
#
#     gdp_per_cap
# 0      1.870161
# 1      1.619505
# 2      1.982456
# 3      1.808470
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              65 non-null     float64
#  1   inflation         65 non-null     float64
#  2   total population  65 non-null     float64
#  3   ferti_cosption    65 non-null     float64
#  4   Agri_land         65 non-null     float64
#  5   gdp_per_cap       65 non-null     float64
# dtypes: float64(6)
# memory usage: 3.2 KB

# %%
X=df.drop(columns='inflation')

# %%
y=df['inflation']

# %%
col=X.columns

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
X_sc=scalar.fit_transform(X)
X=pd.DataFrame(data=X_sc,columns=col)
X
# Out:
#         date  total population  ferti_cosption     Agri_land  gdp_per_cap
# 0   1.705606          1.838263    1.441056e-16  1.628362e-15     1.870161
# 1   1.652306          1.779955    1.441056e-16  1.628362e-15     1.619505
# 2   1.599005          1.721042   -8.656193e-01  1.628362e-15     1.982456
# 3   1.545705          1.655637   -5.915652e-01  3.422625e-02     1.808470
# 4   1.492405          1.586312   -6.193097e-01  6.710283e-01     1.437620
# ..       ...               ...             ...           ...          ...
# 60 -1.492405         -1.266619    2.647611e-01  1.130684e-01    -1.027295
# 61 -1.545705         -1.287562   -1.696793e-01 -6.071244e-01    -1.045760
# 62 -1.599005         -1.307567   -1.038333e+00 -6.677722e-01    -1.054452
# 63 -1.652306         -1.326693    2.065864e+00 -8.345537e-01    -1.058070
# 64 -1.705606         -1.345464    1.441056e-16  1.628362e-15    -1.070131
#
# [65 rows x 5 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=10,test_size=.2)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.16718774092588506
